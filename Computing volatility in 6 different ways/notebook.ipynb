# %%
pip install yfinance --upgrade --no-cache-dir
# Out:
# Requirement already satisfied: yfinance in c:\users\krish\miniconda3\lib\site-packages (0.2.61)
# Requirement already satisfied: requests>=2.31 in c:\users\krish\miniconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: pytz>=2022.5 in c:\users\krish\miniconda3\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\krish\miniconda3\lib\site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\krish\miniconda3\lib\site-packages (from yfinance) (4.13.4)
# Requirement already satisfied: websockets>=13.0 in c:\users\krish\miniconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\krish\miniconda3\lib\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\krish\miniconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\krish\miniconda3\lib\site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\krish\miniconda3\lib\site-packages (from yfinance) (6.30.2)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\krish\miniconda3\lib\site-packages (from yfinance) (0.10.0)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\krish\miniconda3\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\krish\miniconda3\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\krish\miniconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\krish\miniconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.7)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\krish\miniconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\krish\miniconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2024.12.14)
# Requirement already satisfied: pycparser in c:\users\krish\miniconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\krish\miniconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\krish\miniconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\krish\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\krish\miniconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\krish\miniconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\krish\miniconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Computing Volatility in 6 different ways

# %% [markdown]
# Statistical volatility (also called historic or realized volatility) is a measurement of how much the price or returns of stock value. It’s used to optimize portfolios, detect regime changes, and price derivatives. The most common way to measure statistical volatility is the standard deviation.
#
# Unfortunately, there are some downsides to using standard deviation that most people don’t consider.

# %%
import math
import numpy as np  
import yfinance as yf
import time

# time.sleep(30)

data = yf.download("AAPL", start="2019-01-01", end="2023-01-01", threads= False)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# One simple line of code, with the stock name, start and end date and there we have 4 years of data. What a time to be alive!

# %%
data['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Standard Deviation
# We'll start with the standard deviation. Standard deviation measures how widely returns are dispersed from the average return. It’s the most common (and biased) estimator of volatility.

# %%
def standard_deviation(price_data, window = 30, trading_periods = 252, clean = True):
    log_return = (price_data["Close"]/price_data["Close"].shift(1)).apply(np.log)
    result = log_return.rolling(window = window, center = False).std() * math.sqrt(trading_periods)
    
    if clean:
        return result.dropna()
    else:
        return result

# %%
standard_deviation(data).plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Parkinson Volatility
# Parkinson's volatility uses the stock’s high and low price of the day rather than just close to close prices. It’s useful to capture large price movements during the day.

# %%
def parkinson(price_data, window=30, trading_periods=252, clean=True):
    
    rs = (1.0 / (4.0 * math.log(2.0))) * (
        (price_data["High"] / price_data["Low"]).apply(np.log)
    ) ** 2.0

    def f(v):
        return (trading_periods * v.mean()) ** 0.5

    result = rs.rolling(window=window, center=False).apply(func=f)

    if clean:
        return result.dropna()
    else:
        return result

# %%
parkinson(data).plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## German-klass
# Garman-Klass volatility extends Parkinson's volatility by taking into account the opening and closing price. As markets are most active during the opening and closing of a trading session, it makes volatility estimation more accurate.

# %%
def garman_klass(price_data, window=30, trading_periods=252, clean=True):
    
    log_hl = (price_data["High"] / price_data["Low"]).apply(np.log)
    log_co = (price_data["Close"] / price_data["Open"]).apply(np.log)

    rs = 0.5 * log_hl ** 2 - (2 * math.log(2) - 1) * log_co ** 2

    def f(v):
        return (trading_periods * v.mean()) ** 0.5

    result = rs.rolling(window=window, center=False).apply(func=f)

    if clean:
        return result.dropna()
    else:
        return result

# %%
garman_klass(data).plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Hodges-Tompkins
# Hodges-Tompkins volatility is a bias correction for estimation using an overlapping data sample that produces unbiased estimates and a substantial gain in efficiency.

# %%
def hodges_tompkins(price_data, window=30, trading_periods=252, clean=True):
    
    log_return = (price_data["Close"] / price_data["Close"].shift(1)).apply(np.log)

    vol = log_return.rolling(window=window, center=False).std() * math.sqrt(
        trading_periods
    )

    h = window
    n = (log_return.count() - h) + 1

    adj_factor = 1.0 / (1.0 - (h / n) + ((h ** 2 - 1) / (3 * n ** 2)))

    result = vol * adj_factor

    if clean:
        return result.dropna()
    else:
        return

# %%
hodges_tompkins(data).plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Rogers-Satchel
# Rogers-Satchell is an estimator for measuring the volatility of securities with an average return not equal to zero. Unlike Parkinson and Garman-Klass estimators, Rogers-Satchell incorporates a drift term (mean return not equal to zero).

# %%
def rogers_satchell(price_data, window=30, trading_periods=252, clean=True):
    
    log_ho = (price_data["High"] / price_data["Open"]).apply(np.log)
    log_lo = (price_data["Low"] / price_data["Open"]).apply(np.log)
    log_co = (price_data["Close"] / price_data["Open"]).apply(np.log)

    rs = log_ho * (log_ho - log_co) + log_lo * (log_lo - log_co)

    def f(v):
        return (trading_periods * v.mean()) ** 0.5

    result = rs.rolling(window=window, center=False).apply(func=f)

    if clean:
        return result.dropna()
    else:
        return result

# %%
rogers_satchell(data).plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Ynag-Zhang
# Yang-Zhang volatility is the combination of the overnight (close-to-open volatility), a weighted average of the Rogers-Satchell volatility and the day's open-to-close volatility.

# %%
def yang_zhang(price_data, window=30, trading_periods=252, clean=True):
    
    log_ho = (price_data["High"] / price_data["Open"]).apply(np.log)
    log_lo = (price_data["Low"] / price_data["Open"]).apply(np.log)
    log_co = (price_data["Close"] / price_data["Open"]).apply(np.log)

    log_oc = (price_data["Open"] / price_data["Close"].shift(1)).apply(np.log)
    log_oc_sq = log_oc ** 2

    log_cc = (price_data["Close"] / price_data["Close"].shift(1)).apply(np.log)
    log_cc_sq = log_cc ** 2

    rs = log_ho * (log_ho - log_co) + log_lo * (log_lo - log_co)

    close_vol = log_cc_sq.rolling(window=window, center=False).sum() * (
        1.0 / (window - 1.0)
    )
    open_vol = log_oc_sq.rolling(window=window, center=False).sum() * (
        1.0 / (window - 1.0)
    )
    window_rs = rs.rolling(window=window, center=False).sum() * (1.0 / (window - 1.0))

    k = 0.34 / (1.34 + (window + 1) / (window - 1))
    result = (open_vol + k * close_vol + (1 - k) * window_rs).apply(
        np.sqrt
    ) * math.sqrt(trading_periods)

    if clean:
        return result.dropna()
    else:
        return result

# %%
yang_zhang(data).plot()
# Out:
# <Axes: xlabel='Date'>
